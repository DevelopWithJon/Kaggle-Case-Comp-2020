# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/data-science-bowl-2019/test.csv
# /kaggle/input/data-science-bowl-2019/specs.csv
# /kaggle/input/data-science-bowl-2019/train.csv
# /kaggle/input/data-science-bowl-2019/train_labels.csv
# /kaggle/input/data-science-bowl-2019/sample_submission.csv

# %%
sample_submission = pd.read_csv("../input/data-science-bowl-2019/sample_submission.csv")
specs = pd.read_csv("../input/data-science-bowl-2019/specs.csv")
test = pd.read_csv("../input/data-science-bowl-2019/test.csv")
train = pd.read_csv("../input/data-science-bowl-2019/train.csv")
train_labels = pd.read_csv("../input/data-science-bowl-2019/train_labels.csv")

# %% [markdown]
# # These are the names of our data sets
#  - sample_submission __WE DON"T NEED THIS__
#  - specs
#  - test
#  - train
#  - train_lables
#
#  ## Let's sample 2MM rows from the data set, just to make it a bit more managble...for now >:)

# %%
train_samp = train.sample(2000000)

train_samp.shape
# Out:
# (2000000, 11)

# %%
test_samp = test.sample(500000)
test_samp.shape
# Out:
# (500000, 11)

# %%
train_samp = train_samp[train_samp.event_count > 9]

# %%
train_samp.shape
# Out:
# (1787705, 11)

# %%
train_samp.head()
# Out:
#           event_id      game_session                 timestamp  \
# 3519088   804ee27f  a0758af38ae21380  2019-09-13T18:55:39.641Z
# 10943909  beb0a7b9  2319719a77de5976  2019-08-19T02:24:42.642Z
# 9918978   499edb7c  2d169994f46fbbd1  2019-07-28T02:15:03.335Z
# 9291008   bcceccc6  95a9e01f262e30af  2019-09-22T15:41:34.305Z
# 3141231   dcaede90  0809f0c61d7cbca1  2019-10-04T20:23:34.608Z
#
#                                                  event_data installation_id  \
# 3519088   {"weights":3,"target_weight":3,"correct":true,...        4da2e262
# 10943909  {"description":"That one was so low!","identif...        f726e95c
# 9918978   {"side":"right","layout":{"left":{"chickens":0...        de0a0baf
# 9291008   {"coordinates":{"x":47,"y":250,"stage_width":1...        cff5a334
# 3141231   {"level":4,"round":6,"event_count":65,"game_ti...        45f35b9a
#
#           event_count  event_code  game_time                        title  \
# 3519088            23        4020      29060                  Pan Balance
# 10943909           39        3010      48893         Fireworks (Activity)
# 9918978            30        4020      28125  Chicken Balancer (Activity)
# 9291008           135        4070     218601                     Air Show
# 3141231            65        2040     103449                  Scrub-A-Dub
#
#               type         world
# 3519088       Game  CRYSTALCAVES
# 10943909  Activity   TREETOPCITY
# 9918978   Activity  CRYSTALCAVES
# 9291008       Game   TREETOPCITY
# 3141231       Game     MAGMAPEAK

# %% [markdown]
# # As you can see, we have 2MM records with 11 variables

# %%
train_samp.head(5)
# Out:
#           event_id      game_session                 timestamp  \
# 3519088   804ee27f  a0758af38ae21380  2019-09-13T18:55:39.641Z
# 10943909  beb0a7b9  2319719a77de5976  2019-08-19T02:24:42.642Z
# 9918978   499edb7c  2d169994f46fbbd1  2019-07-28T02:15:03.335Z
# 9291008   bcceccc6  95a9e01f262e30af  2019-09-22T15:41:34.305Z
# 3141231   dcaede90  0809f0c61d7cbca1  2019-10-04T20:23:34.608Z
#
#                                                  event_data installation_id  \
# 3519088   {"weights":3,"target_weight":3,"correct":true,...        4da2e262
# 10943909  {"description":"That one was so low!","identif...        f726e95c
# 9918978   {"side":"right","layout":{"left":{"chickens":0...        de0a0baf
# 9291008   {"coordinates":{"x":47,"y":250,"stage_width":1...        cff5a334
# 3141231   {"level":4,"round":6,"event_count":65,"game_ti...        45f35b9a
#
#           event_count  event_code  game_time                        title  \
# 3519088            23        4020      29060                  Pan Balance
# 10943909           39        3010      48893         Fireworks (Activity)
# 9918978            30        4020      28125  Chicken Balancer (Activity)
# 9291008           135        4070     218601                     Air Show
# 3141231            65        2040     103449                  Scrub-A-Dub
#
#               type         world
# 3519088       Game  CRYSTALCAVES
# 10943909  Activity   TREETOPCITY
# 9918978   Activity  CRYSTALCAVES
# 9291008       Game   TREETOPCITY
# 3141231       Game     MAGMAPEAK

# %%
train_samp = train_samp[train_samp.type == "Assessment"]

# %%
train_samp.shape
# Out:
# (131074, 11)

# %%
train_labels.head()
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %% [markdown]
# # cleaning

# %%
def encode_title(train_samp, test_samp, train_labels):
    # encode title
    train_samp['Train_Event_Code'] = list(map(lambda x, y: str(x) + '_' + str(y), train_samp['title'], train_samp['event_code']))
    test_samp['Test_Event_Code'] = list(map(lambda x, y: str(x) + '_' + str(y), test_samp['title'], test_samp['event_code']))
    all_title_event_code = list(set(train_samp["Train_Event_Code"].unique()).union(test_samp["Test_Event_Code"].unique()))
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train_samp['title'].unique()).union(set(test_samp['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train_samp['event_code'].unique()).union(set(test_samp['event_code'].unique())))
    list_of_event_id = list(set(train_samp['event_id'].unique()).union(set(test_samp['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train_samp['world'].unique()).union(set(test_samp['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
    activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train_samp[train_samp['type'] == 'Assessment']['title'].value_counts().index).union(set(test_samp[test_samp['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train_samp['title'] = train_samp['title'].map(activities_map)
    test_samp['title'] = test_samp['title'].map(activities_map)
    train_samp['world'] = train_samp['world'].map(activities_world)
    test_samp['world'] = test_samp['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train_samp['timestamp'] = pd.to_datetime(train_samp['timestamp'])
    test_samp['timestamp'] = pd.to_datetime(test_samp['timestamp'])
    
    
    return train_samp, test_samp, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code

# %%
encode_title(train_samp, test_samp, train_labels)
# Out:
# (          event_id      game_session                        timestamp  \
#  6683986   562cec5f  da529955958f8516 2019-09-17 15:22:52.107000+00:00
#  3495351   37ee8496  692c331cc9930d42 2019-10-06 21:05:20.368000+00:00
#  776492    ea296733  f4afaa7202e7d881 2019-07-27 19:38:01.686000+00:00
#  8678995   df4fe8b6  c3cb0324bee98fd9 2019-09-18 13:40:20.892000+00:00
#  6412587   3d0b9317  19c5c834ab82e0cc 2019-09-06 21:22:37.917000+00:00
#  ...            ...               ...                              ...
#  919922    acf5c23f  3dbb258397599ebb 2019-08-21 18:00:57.118000+00:00
#  4972497   c74f40cd  0209cef7de1248c4 2019-10-13 00:44:55.415000+00:00
#  10443012  1375ccb7  5d7f16f15f63860a 2019-08-21 19:03:59.578000+00:00
#  412129    3ee399c3  fd27f7c1de0a63a8 2019-08-05 23:48:29.158000+00:00
#  6096785   a8efe47b  1630c9bb2a39186d 2019-10-12 18:09:23.826000+00:00
#
#                                                   event_data installation_id  \
#  6683986   {"weight":2,"destination":"right","pillars":[]...        961879cd
#  3495351   {"bucket":1,"buckets":[0,0,0],"coordinates":{"...        4d7d3d97
#  776492    {"description":"Uh oh. Looks like you need to ...        1192a921
#  8678995   {"description":"Uh oh. Looks like you need to ...        c342556e
#  6412587   {"weight":1,"coordinates":{"x":884,"y":414,"st...        8e6996b6
#  ...                                                     ...             ...
#  919922    {"coordinates":{"x":391,"y":626,"stage_width":...        14e76b17
#  4972497   {"description":"Alright! This one is the littl...        6f28047e
#  10443012  {"description":"How many units tall is each bi...        ec9a823d
#  412129    {"coordinates":{"x":754,"y":314,"stage_width":...        08987c08
#  6096785   {"weight":3,"pillars":[],"coordinates":{"x":89...        86c58053
#
#            event_count  event_code  game_time  title        type  world  \
#  6683986            13        4025       6759      4  Assessment      3
#  3495351            66        4030      62713     36  Assessment      0
#  776492            128        3020     150214      4  Assessment      3
#  8678995            60        3120      76582      4  Assessment      3
#  6412587           167        4040     115832      4  Assessment      3
#  ...               ...         ...        ...    ...         ...    ...
#  919922             15        4070       9494      1  Assessment      3
#  4972497            43        3121      33662     12  Assessment      2
#  10443012           27        3010      36303     19  Assessment      2
#  412129            236        4070     122004     36  Assessment      0
#  6096785            11        4030       5825      4  Assessment      3
#
#                             Train_Event_Code
#  6683986      Chest Sorter (Assessment)_4025
#  3495351   Cauldron Filler (Assessment)_4030
#  776492       Chest Sorter (Assessment)_3020
#  8678995      Chest Sorter (Assessment)_3120
#  6412587      Chest Sorter (Assessment)_4040
#  ...                                     ...
#  919922      Cart Balancer (Assessment)_4070
#  4972497   Mushroom Sorter (Assessment)_3121
#  10443012    Bird Measurer (Assessment)_3010
#  412129    Cauldron Filler (Assessment)_4070
#  6096785      Chest Sorter (Assessment)_4030
#
#  [131074 rows x 12 columns],
#           event_id      game_session                        timestamp  \
#  490315   76babcde  37e18e777f0f041e 2019-09-14 20:57:40.243000+00:00
#  137862   a592d54e  6905a913061720ed 2019-10-01 16:43:25.992000+00:00
#  915552   e5c9df6f  14572b12cecd6083 2019-09-12 21:48:36.273000+00:00
#  1122715  0a08139c  a7f96e21af05e882 2019-08-25 11:59:42.328000+00:00
#  529361   df4940d3  309fe011e8ab3e3d 2019-08-21 20:26:03.266000+00:00
#  ...           ...               ...                              ...
#  77520    ac92046e  148c8702738ce4aa 2019-08-28 01:46:23.770000+00:00
#  176472   cf82af56  94bda5a0bede61a1 2019-09-18 18:07:06.650000+00:00
#  345691   587b5989  38d6f24199ef96c5 2019-09-15 20:30:20.423000+00:00
#  239478   2fb91ec1  e7189e6769c4e83b 2019-09-19 15:53:43.128000+00:00
#  208113   bcceccc6  ab2ded207cc4a51c 2019-08-13 20:12:15.345000+00:00
#
#                                                  event_data installation_id  \
#  490315   {"coordinates":{"x":401,"y":153,"stage_width":...        76562474
#  137862   {"target_weight":4,"table_weights":4,"starting...        1ed372f8
#  915552   {"description":"We did it!  There's one round ...        ccb21848
#  1122715  {"description":"Let's put this bug back where ...        f86a6ed4
#  529361   {"description":"I'll add this one to your coll...        7b728c89
#  ...                                                    ...             ...
#  77520    {"description":"I bet you could get her cleane...        12771ee9
#  176472   {"coordinates":{"x":1560,"y":289,"stage_width"...        293c26ac
#  345691   {"coordinates":{"x":984,"y":378,"stage_width":...        4ff2702e
#  239478   {"cloud":"middle","cloud_size":3,"water_level"...        36025ee6
#  208113   {"coordinates":{"x":97,"y":305,"stage_width":1...        2e6923d6
#
#           event_count  event_code  game_time  title      type  world  \
#  490315            68        4070     118560      9      Game      0
#  137862           121        2020     158987     31      Game      3
#  915552            62        3121     105094     35      Game      3
#  1122715          302        3010     260978     37  Activity      2
#  529361            86        3110     182443     41  Activity      0
#  ...              ...         ...        ...    ...       ...    ...
#  77520            209        3120     149391     40      Game      0
#  176472           276        4070     173131     40      Game      0
#  345691            79        4070     217288     15      Game      2
#  239478            55        4025      50567     10  Activity      0
#  208113            67        4070      68030     28      Game      2
#
#                         Test_Event_Code
#  490315                  Dino Dive_4070
#  137862                Pan Balance_2020
#  915552                Leaf Leader_3121
#  1122715   Bug Measurer (Activity)_3010
#  529361   Bottle Filler (Activity)_3110
#  ...                                ...
#  77520                 Scrub-A-Dub_3120
#  176472                Scrub-A-Dub_4070
#  345691           All Star Sorting_4070
#  239478   Watering Hole (Activity)_4025
#  208113                   Air Show_4070
#
#  [500000 rows x 12 columns],
#             game_session installation_id  title  num_correct  num_incorrect  \
#  0      6bdf9623adc94d89        0006a69f     12            1              0
#  1      77b8ee947eb84b4e        0006a69f     19            0             11
#  2      901acc108f55a5a1        0006a69f     12            1              0
#  3      9501794defd84e4d        0006a69f     12            1              1
#  4      a9ef3ecb3d1acc6a        0006a69f     19            1              0
#  ...                 ...             ...    ...          ...            ...
#  17685  c996482b11d149dd        ffc90c32     19            1              0
#  17686  b05a02b52d5c1f4c        ffd2871d     36            1              0
#  17687  5448d652309a6324        ffeb0b1b     36            1              2
#  17688  a6885ab824fbc32c        ffeb0b1b     12            0              1
#  17689  dadd1a4d8ac68ab0        ffeb0b1b     36            1              2
#
#         accuracy  accuracy_group
#  0      1.000000               3
#  1      0.000000               0
#  2      1.000000               3
#  3      0.500000               2
#  4      1.000000               3
#  ...         ...             ...
#  17685  1.000000               3
#  17686  1.000000               3
#  17687  0.333333               1
#  17688  0.000000               0
#  17689  0.333333               1
#
#  [17690 rows x 7 columns],
#  {0: 4100,
#   1: 4100,
#   2: 4100,
#   3: 4100,
#   4: 4100,
#   5: 4100,
#   6: 4100,
#   7: 4100,
#   8: 4100,
#   9: 4100,
#   10: 4100,
#   11: 4100,
#   12: 4100,
#   13: 4100,
#   14: 4100,
#   15: 4100,
#   16: 4100,
#   17: 4100,
#   18: 4100,
#   19: 4110,
#   20: 4100,
#   21: 4100,
#   22: 4100,
#   23: 4100,
#   24: 4100,
#   25: 4100,
#   26: 4100,
#   27: 4100,
#   28: 4100,
#   29: 4100,
#   30: 4100,
#   31: 4100,
#   32: 4100,
#   33: 4100,
#   34: 4100,
#   35: 4100,
#   36: 4100,
#   37: 4100,
#   38: 4100,
#   39: 4100,
#   40: 4100,
#   41: 4100,
#   42: 4100,
#   43: 4100},
#  ['Balancing Act',
#   'Cart Balancer (Assessment)',
#   'Fireworks (Activity)',
#   'Happy Camel',
#   'Chest Sorter (Assessment)',
#   'Sandcastle Builder (Activity)',
#   'Treasure Map',
#   'Dino Drink',
#   'Rulers',
#   'Dino Dive',
#   'Watering Hole (Activity)',
#   'Magma Peak - Level 1',
#   'Mushroom Sorter (Assessment)',
#   'Chicken Balancer (Activity)',
#   'Slop Problem',
#   'All Star Sorting',
#   'Honey Cake',
#   'Egg Dropper (Activity)',
#   'Heavy, Heavier, Heaviest',
#   'Bird Measurer (Assessment)',
#   'Chow Time',
#   'Crystals Rule',
#   'Crystal Caves - Level 3',
#   'Ordering Spheres',
#   'Magma Peak - Level 2',
#   'Welcome to Lost Lagoon!',
#   "Pirate's Tale",
#   'Flower Waterer (Activity)',
#   'Air Show',
#   'Tree Top City - Level 3',
#   'Bubble Bath',
#   'Pan Balance',
#   'Crystal Caves - Level 2',
#   'Lifting Heavy Things',
#   'Tree Top City - Level 2',
#   'Leaf Leader',
#   'Cauldron Filler (Assessment)',
#   'Bug Measurer (Activity)',
#   'Crystal Caves - Level 1',
#   'Costume Box',
#   'Scrub-A-Dub',
#   'Bottle Filler (Activity)',
#   '12 Monkeys',
#   'Tree Top City - Level 1'],
#  [2050,
#   4100,
#   4230,
#   5000,
#   4235,
#   2060,
#   4110,
#   5010,
#   2070,
#   2075,
#   2080,
#   2081,
#   2083,
#   3110,
#   4010,
#   3120,
#   3121,
#   4020,
#   4021,
#   4022,
#   4025,
#   4030,
#   4031,
#   3010,
#   4035,
#   4040,
#   3020,
#   3021,
#   4045,
#   2000,
#   4050,
#   2010,
#   2020,
#   4070,
#   2025,
#   2030,
#   4080,
#   2035,
#   2040,
#   4090,
#   4220,
#   4095],
#  {0: 'Balancing Act',
#   1: 'Cart Balancer (Assessment)',
#   2: 'Fireworks (Activity)',
#   3: 'Happy Camel',
#   4: 'Chest Sorter (Assessment)',
#   5: 'Sandcastle Builder (Activity)',
#   6: 'Treasure Map',
#   7: 'Dino Drink',
#   8: 'Rulers',
#   9: 'Dino Dive',
#   10: 'Watering Hole (Activity)',
#   11: 'Magma Peak - Level 1',
#   12: 'Mushroom Sorter (Assessment)',
#   13: 'Chicken Balancer (Activity)',
#   14: 'Slop Problem',
#   15: 'All Star Sorting',
#   16: 'Honey Cake',
#   17: 'Egg Dropper (Activity)',
#   18: 'Heavy, Heavier, Heaviest',
#   19: 'Bird Measurer (Assessment)',
#   20: 'Chow Time',
#   21: 'Crystals Rule',
#   22: 'Crystal Caves - Level 3',
#   23: 'Ordering Spheres',
#   24: 'Magma Peak - Level 2',
#   25: 'Welcome to Lost Lagoon!',
#   26: "Pirate's Tale",
#   27: 'Flower Waterer (Activity)',
#   28: 'Air Show',
#   29: 'Tree Top City - Level 3',
#   30: 'Bubble Bath',
#   31: 'Pan Balance',
#   32: 'Crystal Caves - Level 2',
#   33: 'Lifting Heavy Things',
#   34: 'Tree Top City - Level 2',
#   35: 'Leaf Leader',
#   36: 'Cauldron Filler (Assessment)',
#   37: 'Bug Measurer (Activity)',
#   38: 'Crystal Caves - Level 1',
#   39: 'Costume Box',
#   40: 'Scrub-A-Dub',
#   41: 'Bottle Filler (Activity)',
#   42: '12 Monkeys',
#   43: 'Tree Top City - Level 1'},
#  ['Mushroom Sorter (Assessment)',
#   'Cart Balancer (Assessment)',
#   'Chest Sorter (Assessment)',
#   'Bird Measurer (Assessment)',
#   'Cauldron Filler (Assessment)'],
#  ['e79f3763',
#   '86c924c4',
#   'a1192f43',
#   '71fe8f75',
#   '792530f8',
#   '93edfe2e',
#   '85d1b0de',
#   'b1d5101d',
#   '8af75982',
#   'bcceccc6',
#   '45d01abe',
#   '46cd75b4',
#   '27253bdc',
#   'fd20ea40',
#   '7ad3efc6',
#   'c2baf0bd',
#   'a8876db3',
#   '4d911100',
#   '84b0e0c8',
#   '832735e1',
#   '4d6737eb',
#   '3d0b9317',
#   'e720d930',
#   '47efca07',
#   '15a43e5b',
#   'b5053438',
#   '77c76bc5',
#   '2230fab4',
#   '28ed704e',
#   '5c2f29ca',
#   '13f56524',
#   'beb0a7b9',
#   '2b9272f4',
#   '53c6e11a',
#   '0086365d',
#   '0d18d96c',
#   '14de4c5d',
#   '28a4eb9a',
#   '1af8be29',
#   '587b5989',
#   '8d84fa81',
#   '5be391b5',
#   'c189aaf2',
#   '15eb4a7d',
#   'a5be6304',
#   '2a512369',
#   '7ec0c298',
#   '070a5291',
#   'b88f38da',
#   '15f99afc',
#   '2a444e03',
#   'a76029ee',
#   'dcaede90',
#   '3ccd3f02',
#   '3bf1cf26',
#   'ea296733',
#   '1bb5fbdb',
#   '4b5efe37',
#   'd3640339',
#   'a592d54e',
#   '25fa8af4',
#   'ad2fc29c',
#   'd38c2fd7',
#   'b7530680',
#   '06372577',
#   '89aace00',
#   'c277e121',
#   '9ed8f6da',
#   'a2df0760',
#   'bd612267',
#   'a44b10dc',
#   '6c930e6e',
#   'f806dc10',
#   '6d90d394',
#   'f5b8c21a',
#   '5859dfb6',
#   'b2dba42b',
#   'ad148f58',
#   'd3268efa',
#   'e5c9df6f',
#   '9e4c8c7b',
#   '92687c59',
#   '90d848e0',
#   'bb3e370b',
#   'e080a381',
#   '3bb91dda',
#   '99abe2bb',
#   '5de79a6a',
#   '9c5ef70c',
#   'e37a2b78',
#   'fcfdffb6',
#   'a52b92d5',
#   '731c0cbe',
#   'a16a373e',
#   'a7640a16',
#   '86ba578b',
#   'e694a35b',
#   'e9c52111',
#   '7372e1a5',
#   'b7dc8128',
#   'a8a78786',
#   '795e4a37',
#   'a29c5338',
#   'e64e2cfd',
#   '56bcd38d',
#   '6088b756',
#   '0330ab6a',
#   '56817e2b',
#   '392e14df',
#   '1cf54632',
#   'b120f2ac',
#   '6c517a88',
#   '85de926c',
#   '1beb320a',
#   '5348fd84',
#   '48349b14',
#   'd2e9262e',
#   'c0415e5c',
#   '55115cbd',
#   '5a848010',
#   '562cec5f',
#   '9e34ea74',
#   'd06f75b5',
#   '363c86c9',
#   '3d8c61b0',
#   '77261ab5',
#   '28f975ea',
#   '0db6d71d',
#   '47f43a44',
#   'cfbd47c8',
#   '65a38bf7',
#   'c74f40cd',
#   'bbfe0445',
#   '4c2ec19f',
#   'bd701df8',
#   '7f0836bf',
#   '7961e599',
#   '9de5e594',
#   'ecaab346',
#   'abc5811c',
#   'e7561dd2',
#   '3bb91ced',
#   'fbaf3456',
#   '5290eab1',
#   'ca11f653',
#   'daac11b0',
#   '51102b85',
#   '2dcad279',
#   '499edb7c',
#   'd3f1e122',
#   '9e6b7fb5',
#   '44cb4907',
#   '46b50ba8',
#   'ec138c1c',
#   '9d4e7b25',
#   'd88ca108',
#   '155f62a4',
#   '1325467d',
#   '3323d7e9',
#   '31973d56',
#   '37c53127',
#   'a0faea5d',
#   '4901243f',
#   '33505eae',
#   '3edf6747',
#   '9554a50b',
#   '56cd3b43',
#   'b80e5e84',
#   '884228c8',
#   '4bb2f698',
#   '38074c54',
#   '5b49460a',
#   '8ac7cce4',
#   '6aeafed4',
#   '1375ccb7',
#   '67439901',
#   '532a2afb',
#   'c1cac9a2',
#   '6043a2b4',
#   'f3cd5473',
#   '3bfd1a65',
#   '67aa2ada',
#   '9b01374f',
#   'd51b1749',
#   '7d093bf9',
#   'd2659ab4',
#   'f7e47413',
#   '5d042115',
#   '5c3d2b2f',
#   '5f0eb72c',
#   '2c4e6db0',
#   'b2e5b0f1',
#   'ac92046e',
#   'c58186bf',
#   '02a42007',
#   'c54cf6c5',
#   'c51d8688',
#   'e57dd7af',
#   '3afb49e6',
#   '2dc29e21',
#   '2b058fe3',
#   '49ed92e9',
#   'f54238ee',
#   '022b4259',
#   '262136f4',
#   '93b353f2',
#   'ea321fb1',
#   '250513af',
#   'e3ff61fb',
#   '8b757ab8',
#   '7423acbc',
#   'f71c4741',
#   '65abac75',
#   'cdd22e43',
#   '37937459',
#   'f6947f54',
#   'cf7638f3',
#   '1340b8d7',
#   'f56e0afc',
#   '4ef8cdd3',
#   '1996c610',
#   '3ddc79c3',
#   '74e5f8a7',
#   'cc5087a3',
#   '08ff79ad',
#   '5f5b2617',
#   'd122731b',
#   '363d3849',
#   '6077cc36',
#   '16dffff1',
#   'f93fc684',
#   '37db1c2f',
#   '73757a5e',
#   '76babcde',
#   '222660ff',
#   'd02b7a8e',
#   '7cf1bc53',
#   'a5e9da97',
#   '3dfd4aa4',
#   '7ab78247',
#   'bdf49a58',
#   '99ea62f3',
#   '47026d5f',
#   '5e109ec3',
#   '5e812b27',
#   'a6d66e51',
#   'bfc77bd6',
#   '29bdd9ba',
#   '7da34a02',
#   'df4fe8b6',
#   '0d1da71f',
#   '3393b68b',
#   'd9c005dd',
#   'a1bbe385',
#   '9ce586dd',
#   '90efca10',
#   '9d29771f',
#   '565a3990',
#   '30df3273',
#   '7dfe6d8a',
#   '3b2048ee',
#   '0a08139c',
#   '15ba1109',
#   '6f445b57',
#   '763fc34e',
#   '8d748b58',
#   '08fd73f3',
#   '6bf9e3e1',
#   '05ad839b',
#   '0413e89d',
#   '63f13dd7',
#   '907a054b',
#   '756e5507',
#   '19967db1',
#   '3ee399c3',
#   '923afab1',
#   'd88e8f25',
#   '87d743c1',
#   '461eace6',
#   '26a5a3dd',
#   'd2278a3b',
#   '00c73085',
#   '3dcdda7f',
#   '598f4598',
#   '4e5fc6f5',
#   '8d7e386c',
#   'a8efe47b',
#   '6f8106d9',
#   '5154fc30',
#   'c952eb01',
#   'c7f7f0e1',
#   '84538528',
#   'ab3136ba',
#   '7525289a',
#   '8f094001',
#   'b74258a0',
#   '9b4001e4',
#   '1f19558b',
#   '7d5c30a2',
#   '77ead60d',
#   '6cf7d25c',
#   'f32856e4',
#   'c7128948',
#   'df4940d3',
#   'dcb55a27',
#   'eb2c19cd',
#   '857f21c0',
#   '1cc7cfca',
#   'e7e44842',
#   '29f54413',
#   '2fb91ec1',
#   '04df9b66',
#   'c6971acf',
#   '9b23e8ee',
#   '828e68f9',
#   'de26c3a6',
#   '9ee1c98c',
#   '8fee50e2',
#   '1575e76c',
#   '83c6c409',
#   '90ea0bac',
#   '36fa3ebe',
#   '6f4bd64e',
#   'cb6010f8',
#   '160654fd',
#   'a1e4395d',
#   'f28c589a',
#   'f50fc6c1',
#   '88d4a5be',
#   '4a4c3d21',
#   '3d63345e',
#   '7040c096',
#   'd45ed6a1',
#   '895865f3',
#   '51311d7a',
#   '16667cc5',
#   'e04fb33d',
#   '26fd2d99',
#   '736f9581',
#   'cb1178ad',
#   'cf82af56',
#   'acf5c23f',
#   '58a0de5c',
#   'ecc36b7f',
#   '804ee27f',
#   '6f4adc4b',
#   '71e712d8',
#   'e5734469',
#   'db02c830',
#   'e4f1efe6',
#   '91561152',
#   '5e3ea25a',
#   'c7fe2a55',
#   '17113b36',
#   '28520915',
#   '69fdac0a',
#   '3afde5dd',
#   'd185d3ea',
#   '30614231',
#   'bc8f2793',
#   '1c178d24',
#   '3babcb9b',
#   '709b1251',
#   'b012cd7f',
#   '37ee8496',
#   '4a09ace1'],
#  ['Chest Sorter (Assessment)_4035',
#   'Bird Measurer (Assessment)_3020',
#   'Chest Sorter (Assessment)_4020',
#   'Slop Problem_2000',
#   'Dino Drink_3120',
#   'Fireworks (Activity)_2000',
#   'Air Show_4090',
#   'Happy Camel_3020',
#   'Bird Measurer (Assessment)_4035',
#   'Happy Camel_4020',
#   'Chow Time_2030',
#   'Crystals Rule_3121',
#   'Mushroom Sorter (Assessment)_2030',
#   'Leaf Leader_4070',
#   'Bird Measurer (Assessment)_4070',
#   'Air Show_2060',
#   'Leaf Leader_2075',
#   'Bubble Bath_4010',
#   'Flower Waterer (Activity)_4070',
#   'Flower Waterer (Activity)_4030',
#   'Dino Dive_3110',
#   'Cart Balancer (Assessment)_4070',
#   'Bird Measurer (Assessment)_4030',
#   'Chow Time_4070',
#   'Cauldron Filler (Assessment)_2030',
#   'Happy Camel_3121',
#   'Scrub-A-Dub_4070',
#   'Bubble Bath_2083',
#   'Bubble Bath_3110',
#   'All Star Sorting_4010',
#   'Chest Sorter (Assessment)_3020',
#   'Egg Dropper (Activity)_4090',
#   'Happy Camel_3110',
#   'Egg Dropper (Activity)_4025',
#   'Chow Time_2000',
#   'All Star Sorting_2030',
#   'Chest Sorter (Assessment)_2030',
#   'Pan Balance_2000',
#   'Scrub-A-Dub_2081',
#   'Chow Time_4095',
#   'Sandcastle Builder (Activity)_2000',
#   'Egg Dropper (Activity)_2000',
#   'Bug Measurer (Activity)_4070',
#   'Chow Time_3010',
#   'All Star Sorting_3110',
#   'Watering Hole (Activity)_3010',
#   'Fireworks (Activity)_4090',
#   'All Star Sorting_2000',
#   'Pan Balance_3120',
#   'Chow Time_4080',
#   'Dino Dive_3120',
#   'Flower Waterer (Activity)_4020',
#   'Dino Drink_3021',
#   'Bubble Bath_4230',
#   'Cauldron Filler (Assessment)_3020',
#   'Egg Dropper (Activity)_4020',
#   'Bottle Filler (Activity)_2030',
#   'Scrub-A-Dub_3021',
#   'Chest Sorter (Assessment)_4025',
#   'Bubble Bath_2025',
#   'Pan Balance_3020',
#   'Cauldron Filler (Assessment)_3121',
#   'Chest Sorter (Assessment)_4080',
#   'Bubble Bath_4095',
#   'Chow Time_4035',
#   'Air Show_4020',
#   'Bubble Bath_2030',
#   'Watering Hole (Activity)_5000',
#   'Cart Balancer (Assessment)_3121',
#   'Mushroom Sorter (Assessment)_2020',
#   'Mushroom Sorter (Assessment)_4080',
#   'Pan Balance_4090',
#   'Chow Time_4020',
#   'Leaf Leader_2020',
#   'Dino Dive_3121',
#   'Crystal Caves - Level 3_2000',
#   'Cauldron Filler (Assessment)_4070',
#   'Dino Drink_3010',
#   'Cart Balancer (Assessment)_3021',
#   'Happy Camel_2030',
#   'All Star Sorting_4080',
#   'Mushroom Sorter (Assessment)_2025',
#   'Scrub-A-Dub_4010',
#   'Scrub-A-Dub_3110',
#   'Crystals Rule_3021',
#   'Treasure Map_2000',
#   'Bird Measurer (Assessment)_3010',
#   'Bubble Bath_4070',
#   'Mushroom Sorter (Assessment)_2000',
#   'Air Show_4110',
#   'Scrub-A-Dub_3010',
#   'Egg Dropper (Activity)_4070',
#   'Scrub-A-Dub_2050',
#   'Chow Time_3121',
#   'Pan Balance_4020',
#   'Scrub-A-Dub_3121',
#   'Dino Drink_2020',
#   'Cauldron Filler (Assessment)_4090',
#   'Happy Camel_2020',
#   'Air Show_2070',
#   'Air Show_3121',
#   'Cauldron Filler (Assessment)_3021',
#   'Chicken Balancer (Activity)_4070',
#   'Pan Balance_4025',
#   'Happy Camel_4070',
#   'Happy Camel_2080',
#   'Cart Balancer (Assessment)_4040',
#   'Chicken Balancer (Activity)_2000',
#   'Bird Measurer (Assessment)_2030',
#   'Crystal Caves - Level 1_2000',
#   'Chicken Balancer (Activity)_4035',
#   'Fireworks (Activity)_4030',
#   'Dino Dive_3020',
#   'Chow Time_3021',
#   'Crystals Rule_2030',
#   'Pan Balance_4030',
#   'Chest Sorter (Assessment)_3110',
#   'Chicken Balancer (Activity)_3110',
#   'Fireworks (Activity)_3010',
#   'Mushroom Sorter (Assessment)_3120',
#   'All Star Sorting_4090',
#   'Dino Dive_4070',
#   'Tree Top City - Level 2_2000',
#   'Cauldron Filler (Assessment)_4080',
#   'Bubble Bath_4020',
#   'Leaf Leader_4095',
#   'Dino Dive_3010',
#   'Happy Camel_4095',
#   'Air Show_4100',
#   'Pan Balance_2030',
#   'All Star Sorting_3121',
#   'Flower Waterer (Activity)_3110',
#   'Costume Box_2000',
#   'Bottle Filler (Activity)_3110',
#   'Cauldron Filler (Assessment)_4025',
#   'Sandcastle Builder (Activity)_4080',
#   'Fireworks (Activity)_3110',
#   'Happy Camel_4090',
#   'Bottle Filler (Activity)_4035',
#   'Bug Measurer (Activity)_3010',
#   'Mushroom Sorter (Assessment)_3110',
#   'Cauldron Filler (Assessment)_4100',
#   'Chow Time_2020',
#   'Air Show_4010',
#   'Pan Balance_4100',
#   'Dino Dive_2000',
#   'Cauldron Filler (Assessment)_3110',
#   'Sandcastle Builder (Activity)_3110',
#   'Lifting Heavy Things_2000',
#   'Dino Dive_3021',
#   'Leaf Leader_2030',
#   'Cauldron Filler (Assessment)_2010',
#   'Happy Camel_2081',
#   'Chicken Balancer (Activity)_4030',
#   'Chow Time_3020',
#   'Bubble Bath_3120',
#   'Crystals Rule_4020',
#   'Mushroom Sorter (Assessment)_3121',
#   'Egg Dropper (Activity)_2020',
#   'Chest Sorter (Assessment)_3010',
#   'Watering Hole (Activity)_2000',
#   'Bottle Filler (Activity)_4030',
#   'Happy Camel_4040',
#   'Cart Balancer (Assessment)_4030',
#   'Dino Dive_4010',
#   'Dino Drink_4090',
#   'Pan Balance_4010',
#   'Watering Hole (Activity)_4025',
#   'Cart Balancer (Assessment)_2030',
#   'Leaf Leader_3110',
#   'Scrub-A-Dub_3020',
#   'Welcome to Lost Lagoon!_2000',
#   'Mushroom Sorter (Assessment)_4020',
#   'Sandcastle Builder (Activity)_4030',
#   'Dino Drink_2030',
#   'All Star Sorting_2020',
#   'All Star Sorting_4020',
#   'Cauldron Filler (Assessment)_2020',
#   'Air Show_2030',
#   'Leaf Leader_2070',
#   'Scrub-A-Dub_2083',
#   'Cauldron Filler (Assessment)_4040',
#   'Bird Measurer (Assessment)_2020',
#   'Leaf Leader_4010',
#   'Cart Balancer (Assessment)_4035',
#   'Sandcastle Builder (Activity)_4021',
#   'Leaf Leader_3021',
#   'Bird Measurer (Assessment)_4040',
#   'Scrub-A-Dub_2000',
#   'Air Show_3110',
#   'Bug Measurer (Activity)_4035',
#   'Air Show_4070',
#   'Dino Dive_4020',
#   'Air Show_2000',
#   'Bubble Bath_3021',
#   'Happy Camel_3021',
#   'Happy Camel_4030',
#   'Pan Balance_3121',
#   'All Star Sorting_4035',
#   'Crystals Rule_2000',
#   'Pan Balance_3010',
#   'Bird Measurer (Assessment)_2010',
#   'Cart Balancer (Assessment)_2010',
#   'Bubble Bath_2035',
#   'Fireworks (Activity)_4020',
#   'Bird Measurer (Assessment)_3121',
#   'Chow Time_4030',
#   'All Star Sorting_4070',
#   'Bottle Filler (Activity)_2000',
#   'Chicken Balancer (Activity)_4090',
#   'Bubble Bath_2080',
#   'Sandcastle Builder (Activity)_4070',
#   'Mushroom Sorter (Assessment)_4025',
#   'Cart Balancer (Assessment)_2000',
#   'Pan Balance_2020',
#   'Dino Drink_4031',
#   'Bottle Filler (Activity)_4090',
#   'Tree Top City - Level 3_2000',
#   'Mushroom Sorter (Assessment)_3020',
#   'Watering Hole (Activity)_4020',
#   'Cart Balancer (Assessment)_3010',
#   'Mushroom Sorter (Assessment)_2035',
#   'Chest Sorter (Assessment)_2010',
#   'Chest Sorter (Assessment)_2000',
#   'Chest Sorter (Assessment)_4100',
#   'All Star Sorting_3020',
#   'Heavy, Heavier, Heaviest_2000',
#   'Bubble Bath_4045',
#   'Dino Drink_3121',
#   'Chest Sorter (Assessment)_4070',
#   'Scrub-A-Dub_2030',
#   'All Star Sorting_2025',
#   'Flower Waterer (Activity)_4090',
#   'Watering Hole (Activity)_4070',
#   'Leaf Leader_2060',
#   'Air Show_2075',
#   'Chest Sorter (Assessment)_4090',
#   'Sandcastle Builder (Activity)_3010',
#   'Chicken Balancer (Activity)_4020',
#   'Bottle Filler (Activity)_4020',
#   'Flower Waterer (Activity)_2000',
#   'Mushroom Sorter (Assessment)_4070',
#   'Crystals Rule_3120',
#   '12 Monkeys_2000',
#   'Cauldron Filler (Assessment)_4020',
#   'Chow Time_3120',
#   'Happy Camel_3120',
#   'Sandcastle Builder (Activity)_4090',
#   'Bird Measurer (Assessment)_3021',
#   'Cart Balancer (Assessment)_4100',
#   'All Star Sorting_4030',
#   'Scrub-A-Dub_4090',
#   'Balancing Act_2000',
#   'Dino Drink_4070',
#   'Crystals Rule_2020',
#   'Honey Cake_2000',
#   'Crystal Caves - Level 2_2000',
#   'Happy Camel_4045',
#   'Fireworks (Activity)_4070',
#   'Bottle Filler (Activity)_4070',
#   'Ordering Spheres_2000',
#   'Tree Top City - Level 1_2000',
#   'Chest Sorter (Assessment)_3121',
#   'Dino Dive_2030',
#   'Leaf Leader_3120',
#   'Bird Measurer (Assessment)_3110',
#   'Crystals Rule_4010',
#   'Chow Time_4090',
#   'Flower Waterer (Activity)_4025',
#   'Dino Dive_4090',
#   'Air Show_2020',
#   'Watering Hole (Activity)_3110',
#   'Watering Hole (Activity)_5010',
#   'Dino Drink_2075',
#   'Bubble Bath_4235',
#   'Chicken Balancer (Activity)_4022',
#   'Dino Dive_2070',
#   'Crystals Rule_4090',
#   'Bug Measurer (Activity)_4025',
#   'Bird Measurer (Assessment)_3120',
#   'Dino Drink_4030',
#   'Chicken Balancer (Activity)_4080',
#   'Egg Dropper (Activity)_3110',
#   'Bird Measurer (Assessment)_4080',
#   'Air Show_3020',
#   'Leaf Leader_4090',
#   'Scrub-A-Dub_3120',
#   'Flower Waterer (Activity)_3010',
#   'Happy Camel_3010',
#   'Crystals Rule_3110',
#   'Cart Balancer (Assessment)_4020',
#   'Bird Measurer (Assessment)_4025',
#   'Bird Measurer (Assessment)_4090',
#   'Dino Drink_3020',
#   'Chest Sorter (Assessment)_3120',
#   'Leaf Leader_3010',
#   'Dino Drink_2070',
#   'Watering Hole (Activity)_4021',
#   'Scrub-A-Dub_4020',
#   'Pan Balance_3110',
#   'Leaf Leader_3121',
#   'Dino Drink_2060',
#   'Magma Peak - Level 2_2000',
#   'All Star Sorting_3120',
#   'Bug Measurer (Activity)_4090',
#   'Dino Dive_2020',
#   'Chest Sorter (Assessment)_4030',
#   'Dino Drink_3110',
#   'Bottle Filler (Activity)_3010',
#   'Dino Drink_4010',
#   'Chest Sorter (Assessment)_2020',
#   'Chest Sorter (Assessment)_4040',
#   'Bubble Bath_4040',
#   'Rulers_2000',
#   'Bubble Bath_4090',
#   'Air Show_3021',
#   'Bottle Filler (Activity)_4080',
#   'Cart Balancer (Assessment)_4090',
#   'Flower Waterer (Activity)_4022',
#   'Bug Measurer (Activity)_4030',
#   'Scrub-A-Dub_2080',
#   'Happy Camel_4010',
#   'Mushroom Sorter (Assessment)_4040',
#   'Cauldron Filler (Assessment)_3120',
#   'Crystals Rule_4070',
#   'Mushroom Sorter (Assessment)_3021',
#   'Happy Camel_4035',
#   'Leaf Leader_3020',
#   'All Star Sorting_3010',
#   'Crystals Rule_3020',
#   'Chest Sorter (Assessment)_3021',
#   'Cauldron Filler (Assessment)_4035',
#   'Leaf Leader_2000',
#   'Watering Hole (Activity)_4090',
#   'Cart Balancer (Assessment)_3120',
#   'Bubble Bath_2000',
#   'Mushroom Sorter (Assessment)_2010',
#   'Cart Balancer (Assessment)_3020',
#   'Air Show_3120',
#   'Mushroom Sorter (Assessment)_4035',
#   'Sandcastle Builder (Activity)_4035',
#   'Scrub-A-Dub_2020',
#   'Bug Measurer (Activity)_3110',
#   'Magma Peak - Level 1_2000',
#   'Happy Camel_2083',
#   'Cart Balancer (Assessment)_3110',
#   'Bird Measurer (Assessment)_4020',
#   'Chow Time_3110',
#   'Bubble Bath_3010',
#   'Bubble Bath_3121',
#   'Bubble Bath_2020',
#   'Air Show_3010',
#   'Crystals Rule_4050',
#   "Pirate's Tale_2000",
#   'Chow Time_4010',
#   'Mushroom Sorter (Assessment)_4090',
#   'Bug Measurer (Activity)_2000',
#   'Leaf Leader_4020',
#   'Happy Camel_2000',
#   'Mushroom Sorter (Assessment)_4030',
#   'Bubble Bath_3020',
#   'Scrub-A-Dub_2040',
#   'All Star Sorting_3021',
#   'Cart Balancer (Assessment)_2020',
#   'Mushroom Sorter (Assessment)_3010',
#   'Bottle Filler (Activity)_2020',
#   'Cauldron Filler (Assessment)_3010',
#   'Mushroom Sorter (Assessment)_4100',
#   'Dino Dive_2060',
#   'Pan Balance_4035',
#   'Dino Drink_4020',
#   'Bubble Bath_4220',
#   'Bird Measurer (Assessment)_4110',
#   'Dino Drink_2000',
#   'Egg Dropper (Activity)_3010',
#   'Pan Balance_4070',
#   'Bird Measurer (Assessment)_4100',
#   'Cauldron Filler (Assessment)_2000',
#   'Crystals Rule_3010',
#   'Chicken Balancer (Activity)_3010',
#   'Cauldron Filler (Assessment)_4030',
#   'All Star Sorting_4095',
#   'Sandcastle Builder (Activity)_4020',
#   'Pan Balance_3021',
#   'Bird Measurer (Assessment)_2000'])

# %%
print(train_samp['event_code'].loc[train_samp['title'] ==  "Bird Measurer (Assessment)"])
# Out:
# Series([], Name: event_code, dtype: int64)
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # Constants and parameters declaration
    last_activity = 0
    
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    # new features: time spent in each activity
    last_session_time_sec = 0
    accuracy_groups = {0:0, 1:0, 2:0, 3:0}
    all_assessments = []
    accumulated_accuracy_group = 0
    accumulated_accuracy = 0
    accumulated_correct_attempts = 0 
    accumulated_uncorrect_attempts = 0
    accumulated_actions = 0
    counter = 0
    time_first_activity = float(user_sample['timestamp'].values[0])
    durations = []
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles}
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_title = session['title'].iloc[0]
        session_title_text = activities_labels[session_title]
                    
            
        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            features.update(title_count.copy())
            features.update(title_event_code_count.copy())
            features.update(last_accuracy_title.copy())
            features['installation_session_count'] = sessions_count
            
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            if durations == []:
                features['duration_mean'] = 0
                features['duration_std'] = 0
            else:
                features['duration_mean'] = np.mean(durations)
                features['duration_std'] = np.std(durations)
            durations.append((session.iloc[-1, 2] - session.iloc[0, 2] ).seconds)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)
                
            counter += 1
        
        sessions_count += 1
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')

        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    categoricals = ['session_title']
    return reduce_train, reduce_test, categoricals

# %%
class Base_Model(object):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True):
        self.train_df = train_df
        self.test_df = test_df
        self.features = features
        self.n_splits = n_splits
        self.categoricals = categoricals
        self.target = 'accuracy_group'
        self.cv = self.get_cv()
        self.verbose = verbose
        self.params = self.get_params()
        self.y_pred, self.score, self.model = self.fit()
        
    def train_model(self, train_set, val_set):
        raise NotImplementedError
        
    def get_cv(self):
        cv = StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=42)
        return cv.split(self.train_df, self.train_df[self.target])
    
    def get_params(self):
        raise NotImplementedError
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        raise NotImplementedError
        
    def convert_x(self, x):
        return x
        
    def fit(self):
        oof_pred = np.zeros((len(reduce_train), ))
        y_pred = np.zeros((len(reduce_test), ))
        for fold, (train_idx, val_idx) in enumerate(self.cv):
            x_train, x_val = self.train_df[self.features].iloc[train_idx], self.train_df[self.features].iloc[val_idx]
            y_train, y_val = self.train_df[self.target][train_idx], self.train_df[self.target][val_idx]
            train_set, val_set = self.convert_dataset(x_train, y_train, x_val, y_val)
            model = self.train_model(train_set, val_set)
            conv_x_val = self.convert_x(x_val)
            oof_pred[val_idx] = model.predict(conv_x_val).reshape(oof_pred[val_idx].shape)
            x_test = self.convert_x(self.test_df[self.features])
            y_pred += model.predict(x_test).reshape(y_pred.shape) / self.n_splits
            print('Partial score of fold {} is: {}'.format(fold, eval_qwk_lgb_regr(y_val, oof_pred[val_idx])[1]))
        _, loss_score, _ = eval_qwk_lgb_regr(self.train_df[self.target], oof_pred)
        if self.verbose:
            print('Our oof cohen kappa score is: ', loss_score)
        return y_pred, loss_score, model
